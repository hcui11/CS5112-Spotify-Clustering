# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, MeanShift, Birch, DBSCAN, AffinityPropagation, AgglomerativeClustering, SpectralClustering
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.model_selection import train_test_split
from collections import Counter

data = pd.read_csv('spotify_data/processed_data.csv')

train = data.drop(['genres', 'name', 'key', 'mode', 'explicit', 'duration_ms'], axis=1)

genres = data['genres']
song_names = data['name']
query = ['Bohemian Rhapsody', 'Baby', '13 Preludes, Op. 32: No. 9 in A Major: Allegro moderato']

song_names_train = pd.Series([], dtype=str)
while not pd.Series(query, name='name').isin(song_names_train).all():
    X_train, _, genres_train, _, song_names_train, _ = train_test_split(train, genres, song_names, test_size=0.9) 

scaler = StandardScaler()
scaler.fit(train)
train_scale = scaler.transform(X_train)
genres_train = list(genres_train)
song_names_train = list(song_names_train)

# %%
models = ['KMeans', 'Mean Shift', 'BIRCH', 'DBSCAN', 'Affinity Propagation', 'Agglomerative Clustering', 'Spectral Clustering', 'Gaussian Mixtures']
model_preds = []
s_scores = []
ch_scores = []
db_scores = []

# %% [markdown]
# # KMeans

# %%
model = KMeans(n_clusters=5)
y_pred = model.fit_predict(train_scale)

model_preds.append(y_pred)
s_scores.append(silhouette_score(train_scale, y_pred))
ch_scores.append(calinski_harabasz_score(train_scale, y_pred))
db_scores.append(davies_bouldin_score(train_scale, y_pred))

# %% [markdown]
# # Mean Shift

# %%
model = MeanShift()
y_pred = model.fit_predict(train_scale)

model_preds.append(y_pred)
s_scores.append(silhouette_score(train_scale, y_pred))
ch_scores.append(calinski_harabasz_score(train_scale, y_pred))
db_scores.append(davies_bouldin_score(train_scale, y_pred))

# %% [markdown]
# # BIRCH

# %%
model = Birch(n_clusters=6)
y_pred = model.fit_predict(train_scale)

model_preds.append(y_pred)
s_scores.append(silhouette_score(train_scale, y_pred))
ch_scores.append(calinski_harabasz_score(train_scale, y_pred))
db_scores.append(davies_bouldin_score(train_scale, y_pred))

# %% [markdown]
# # DBSCAN

# %%
model = DBSCAN(eps=1.1, min_samples=30)
predictions = model.fit_predict(train_scale)
y_pred = predictions[predictions != -1]
clustered = train_scale[predictions != -1]
outliers = train_scale[predictions == -1]

model_preds.append(predictions)
s_scores.append(silhouette_score(clustered, y_pred))
ch_scores.append(calinski_harabasz_score(clustered, y_pred))
db_scores.append(davies_bouldin_score(clustered, y_pred))

# %% [markdown]
# # Affinity Propagation

# %%
model = AffinityPropagation(random_state=0)
y_pred = model.fit_predict(train_scale)

model_preds.append(y_pred)
s_scores.append(silhouette_score(train_scale, y_pred))
ch_scores.append(calinski_harabasz_score(train_scale, y_pred))
db_scores.append(davies_bouldin_score(train_scale, y_pred))

# %% [markdown]
# # Agglomerative Clustering

# %%
model = AgglomerativeClustering(n_clusters=8)
y_pred = model.fit_predict(train_scale)

model_preds.append(y_pred)
s_scores.append(silhouette_score(train_scale, y_pred))
ch_scores.append(calinski_harabasz_score(train_scale, y_pred))
db_scores.append(davies_bouldin_score(train_scale, y_pred))

# %% [markdown]
# # Spectral Clustering

# %%
model = SpectralClustering(assign_labels='discretize', n_clusters=5, random_state=0)
y_pred = model.fit_predict(train_scale)

model_preds.append(y_pred)
s_scores.append(silhouette_score(train_scale, y_pred))
ch_scores.append(calinski_harabasz_score(train_scale, y_pred))
db_scores.append(davies_bouldin_score(train_scale, y_pred))

# %% [markdown]
# # Gaussian Mixtures

# %%
model = GaussianMixture(n_components=6)
y_pred = model.fit_predict(train_scale)

model_preds.append(y_pred)
s_scores.append(silhouette_score(train_scale, y_pred))
ch_scores.append(calinski_harabasz_score(train_scale, y_pred))
db_scores.append(davies_bouldin_score(train_scale, y_pred))

# %% [markdown]
# # Comparison

# %%
for i in range(len(models)):
    print(models[i])
    print(f'\tSilhouette Score: {s_scores[i]}')
    print(f'\tCalinski Harabasz Score: {ch_scores[i]}')
    print(f'\tDavies Bouldin Score: {db_scores[i]}')
# Out:
# KMeans
# 	Silhouette Score: 0.1589666117619654
# 	Calinski Harabasz Score: 2707.7357025284164
# 	Davies Bouldin Score: 1.7999845058766095
# Mean Shift
# 	Silhouette Score: 0.3353460244716669
# 	Calinski Harabasz Score: 218.34914860198083
# 	Davies Bouldin Score: 1.7993264197456846
# BIRCH
# 	Silhouette Score: 0.12110591132386934
# 	Calinski Harabasz Score: 1963.3641738392346
# 	Davies Bouldin Score: 1.971576610391206
# DBSCAN
# 	Silhouette Score: 0.3808851056971384
# 	Calinski Harabasz Score: 2017.006058216331
# 	Davies Bouldin Score: 0.8352845457496735
# Affinity Propagation
# 	Silhouette Score: 0.09253461111625143
# 	Calinski Harabasz Score: 212.86266780713402
# 	Davies Bouldin Score: 1.6513249976529818
# Agglomerative Clustering
# 	Silhouette Score: 0.08958472421176161
# 	Calinski Harabasz Score: 1725.9693885415609
# 	Davies Bouldin Score: 1.8601780431213153
# Spectral Clustering
# 	Silhouette Score: 0.25588614056313874
# 	Calinski Harabasz Score: 833.8494413700105
# 	Davies Bouldin Score: 1.4872743811449018
# Gaussian Mixtures
# 	Silhouette Score: -0.003085867801807535
# 	Calinski Harabasz Score: 948.4599932439868
# 	Davies Bouldin Score: 7.452081939804984

# %% [markdown]
# # Recommendations

# %%
recs_shown = 10

for i in range(len(models)):
    print(models[i])
    for song in query:
        song_index = song_names_train.index(song)
        values = train_scale[song_index]
        label = model_preds[i][song_index]
        dists = np.sqrt(((train_scale - values) ** 2).sum(axis=1))
        dists[model_preds[i] != label] = np.Inf
        recs = np.argsort(dists)[1:recs_shown + 1]
        print(f'\tRecommendations Based On {song}, genres = {genres_train[song_index]}')
        for rec in recs:
            print(f'\t\t{song_names_train[rec]}, genres = {genres_train[rec]}')
# Out:
# KMeans
# 	Recommendations Based On Bohemian Rhapsody, genres = ['modern', 'pop', 'rock']
# 		Look After You, genres = ['modern', 'pop', 'rock']
# 		East To West, genres = ['alternative', 'rock']
# 		Bored, genres = ['alternative', 'grunge', 'indie', 'metal', 'modern', 'rap', 'rock']
# 		It Ends Tonight, genres = ['grunge', 'modern', 'pop', 'punk', 'rock']
# 		Born To Die, genres = ['art', 'pop']
# 		Until We Meet Again, genres = ['dance', 'pop']
# 		Princess of China, genres = ['pop', 'wave']
# 		Mi soledad y yo, genres = ['latin', 'pop', 'rock']
# 		Eventually, genres = ['psychedelic']
# 		I Feel Pretty / Unpretty (Glee Cast Version), genres = ['pop']
# 	Recommendations Based On Baby, genres = ['funk', 'rock']
# 		Blood Of Eden, genres = ['album', 'art', 'classic', 'dance', 'mellow gold', 'pop', 'rock', 'soft', 'wave']
# 		Skulls, genres = ['alternative', 'pop', 'rock']
# 		Namaste - Alternate Mix / No Vocals, genres = ['alternative', 'hip hop', 'rap', 'rock']
# 		You're My Latest, My Greatest Inspiration, genres = ['classic', 'contemporary', 'funk', 'soul', 'southern', 'swing']
# 		Homeless Brother, genres = ['adult standards', 'classic', 'folk', 'mellow gold', 'rock', 'singer songwriter', 'soft', 'traditional']
# 		A Place to Fall Apart (with Janie Fricke), genres = ['country', 'rock']
# 		עוף גוזל, genres = ['classic', 'pop', 'rock', 'singer songwriter']
# 		It Don't Matter to Me, genres = ['adult standards', 'folk', 'mellow gold', 'rock', 'soft']
# 		Rosemary - 2013 Remaster, genres = ['classic', 'country', 'folk', 'mellow gold', 'psychedelic', 'rock', 'roots']
# 		Desperado, genres = ['country', 'rock', 'roots']
# 	Recommendations Based On 13 Preludes, Op. 32: No. 9 in A Major: Allegro moderato, genres = ['classical', 'romantic', 'romantic era']
# 		Impromptu No. 1 in A-Flat Major, Op. 29, genres = ['classical', 'romantic', 'romantic era']
# 		Lucy Takes Gull Cottage, genres = ['classic']
# 		Chopin: Nocturne No. 19 in E Minor, Op. Posth. 72 No. 1, genres = ['classical', 'romantic', 'romantic era']
# 		Ballade No. 4 in F Minor, Op. 52, genres = ['classical', 'romantic', 'romantic era']
# 		Mazurkas, Op. 59: No. 3 in F-Sharp Minor, genres = ['classical', 'romantic', 'romantic era']
# 		12 études, Op. 10: No. 9 in F Minor, genres = ['classical', 'romantic', 'romantic era']
# 		Straniero tra gli angeli, genres = ['classic', 'pop', 'swing']
# 		Chopin: Nocturne No. 2 in E-Flat Major, Op. 9 No. 2, genres = ['classical', 'romantic', 'romantic era']
# 		Nocturne in B Major, Op. 9, No. 3 - 2001 Remastered, genres = ['classical', 'romantic', 'romantic era']
# 		Allemande (beginning), genres = ['classical']
# Mean Shift
# 	Recommendations Based On Bohemian Rhapsody, genres = ['modern', 'pop', 'rock']
# 		Look After You, genres = ['modern', 'pop', 'rock']
# 		East To West, genres = ['alternative', 'rock']
# 		Bored, genres = ['alternative', 'grunge', 'indie', 'metal', 'modern', 'rap', 'rock']
# 		It Ends Tonight, genres = ['grunge', 'modern', 'pop', 'punk', 'rock']
# 		Born To Die, genres = ['art', 'pop']
# 		Until We Meet Again, genres = ['dance', 'pop']
# 		Princess of China, genres = ['pop', 'wave']
# 		Mi soledad y yo, genres = ['latin', 'pop', 'rock']
# 		Eventually, genres = ['psychedelic']
# 		I Feel Pretty / Unpretty (Glee Cast Version), genres = ['pop']
# 	Recommendations Based On Baby, genres = ['funk', 'rock']
# 		Blood Of Eden, genres = ['album', 'art', 'classic', 'dance', 'mellow gold', 'pop', 'rock', 'soft', 'wave']
# 		Skulls, genres = ['alternative', 'pop', 'rock']
# 		Namaste - Alternate Mix / No Vocals, genres = ['alternative', 'hip hop', 'rap', 'rock']
# 		You're My Latest, My Greatest Inspiration, genres = ['classic', 'contemporary', 'funk', 'soul', 'southern', 'swing']
# 		Homeless Brother, genres = ['adult standards', 'classic', 'folk', 'mellow gold', 'rock', 'singer songwriter', 'soft', 'traditional']
# 		A Place to Fall Apart (with Janie Fricke), genres = ['country', 'rock']
# 		עוף גוזל, genres = ['classic', 'pop', 'rock', 'singer songwriter']
# 		It Don't Matter to Me, genres = ['adult standards', 'folk', 'mellow gold', 'rock', 'soft']
# 		Rosemary - 2013 Remaster, genres = ['classic', 'country', 'folk', 'mellow gold', 'psychedelic', 'rock', 'roots']
# 		Desperado, genres = ['country', 'rock', 'roots']
# 	Recommendations Based On 13 Preludes, Op. 32: No. 9 in A Major: Allegro moderato, genres = ['classical', 'romantic', 'romantic era']
# 		Impromptu No. 1 in A-Flat Major, Op. 29, genres = ['classical', 'romantic', 'romantic era']
# 		Lucy Takes Gull Cottage, genres = ['classic']
# 		Chopin: Nocturne No. 19 in E Minor, Op. Posth. 72 No. 1, genres = ['classical', 'romantic', 'romantic era']
# 		Ballade No. 4 in F Minor, Op. 52, genres = ['classical', 'romantic', 'romantic era']
# 		Mazurkas, Op. 59: No. 3 in F-Sharp Minor, genres = ['classical', 'romantic', 'romantic era']
# 		12 études, Op. 10: No. 9 in F Minor, genres = ['classical', 'romantic', 'romantic era']
# 		Straniero tra gli angeli, genres = ['classic', 'pop', 'swing']
# 		Chopin: Nocturne No. 2 in E-Flat Major, Op. 9 No. 2, genres = ['classical', 'romantic', 'romantic era']
# 		Nocturne in B Major, Op. 9, No. 3 - 2001 Remastered, genres = ['classical', 'romantic', 'romantic era']
# 		Allemande (beginning), genres = ['classical']
# BIRCH
# 	Recommendations Based On Bohemian Rhapsody, genres = ['modern', 'pop', 'rock']
# 		Look After You, genres = ['modern', 'pop', 'rock']
# 		East To West, genres = ['alternative', 'rock']
# 		Bored, genres = ['alternative', 'grunge', 'indie', 'metal', 'modern', 'rap', 'rock']
# 		It Ends Tonight, genres = ['grunge', 'modern', 'pop', 'punk', 'rock']
# 		Born To Die, genres = ['art', 'pop']
# 		Until We Meet Again, genres = ['dance', 'pop']
# 		Princess of China, genres = ['pop', 'wave']
# 		Mi soledad y yo, genres = ['latin', 'pop', 'rock']
# 		Eventually, genres = ['psychedelic']
# 		I Feel Pretty / Unpretty (Glee Cast Version), genres = ['pop']
# 	Recommendations Based On Baby, genres = ['funk', 'rock']
# 		Blood Of Eden, genres = ['album', 'art', 'classic', 'dance', 'mellow gold', 'pop', 'rock', 'soft', 'wave']
# 		Skulls, genres = ['alternative', 'pop', 'rock']
# 		Namaste - Alternate Mix / No Vocals, genres = ['alternative', 'hip hop', 'rap', 'rock']
# 		You're My Latest, My Greatest Inspiration, genres = ['classic', 'contemporary', 'funk', 'soul', 'southern', 'swing']
# 		Homeless Brother, genres = ['adult standards', 'classic', 'folk', 'mellow gold', 'rock', 'singer songwriter', 'soft', 'traditional']
# 		A Place to Fall Apart (with Janie Fricke), genres = ['country', 'rock']
# 		עוף גוזל, genres = ['classic', 'pop', 'rock', 'singer songwriter']
# 		It Don't Matter to Me, genres = ['adult standards', 'folk', 'mellow gold', 'rock', 'soft']
# 		Rosemary - 2013 Remaster, genres = ['classic', 'country', 'folk', 'mellow gold', 'psychedelic', 'rock', 'roots']
# 		Desperado, genres = ['country', 'rock', 'roots']
# 	Recommendations Based On 13 Preludes, Op. 32: No. 9 in A Major: Allegro moderato, genres = ['classical', 'romantic', 'romantic era']
# 		Impromptu No. 1 in A-Flat Major, Op. 29, genres = ['classical', 'romantic', 'romantic era']
# 		Lucy Takes Gull Cottage, genres = ['classic']
# 		Chopin: Nocturne No. 19 in E Minor, Op. Posth. 72 No. 1, genres = ['classical', 'romantic', 'romantic era']
# 		Ballade No. 4 in F Minor, Op. 52, genres = ['classical', 'romantic', 'romantic era']
# 		Mazurkas, Op. 59: No. 3 in F-Sharp Minor, genres = ['classical', 'romantic', 'romantic era']
# 		12 études, Op. 10: No. 9 in F Minor, genres = ['classical', 'romantic', 'romantic era']
# 		Straniero tra gli angeli, genres = ['classic', 'pop', 'swing']
# 		Chopin: Nocturne No. 2 in E-Flat Major, Op. 9 No. 2, genres = ['classical', 'romantic', 'romantic era']
# 		Nocturne in B Major, Op. 9, No. 3 - 2001 Remastered, genres = ['classical', 'romantic', 'romantic era']
# 		Allemande (beginning), genres = ['classical']
# DBSCAN
# 	Recommendations Based On Bohemian Rhapsody, genres = ['modern', 'pop', 'rock']
# 		Look After You, genres = ['modern', 'pop', 'rock']
# 		East To West, genres = ['alternative', 'rock']
# 		Bored, genres = ['alternative', 'grunge', 'indie', 'metal', 'modern', 'rap', 'rock']
# 		It Ends Tonight, genres = ['grunge', 'modern', 'pop', 'punk', 'rock']
# 		Born To Die, genres = ['art', 'pop']
# 		Until We Meet Again, genres = ['dance', 'pop']
# 		Princess of China, genres = ['pop', 'wave']
# 		Mi soledad y yo, genres = ['latin', 'pop', 'rock']
# 		Eventually, genres = ['psychedelic']
# 		I Feel Pretty / Unpretty (Glee Cast Version), genres = ['pop']
# 	Recommendations Based On Baby, genres = ['funk', 'rock']
# 		Blood Of Eden, genres = ['album', 'art', 'classic', 'dance', 'mellow gold', 'pop', 'rock', 'soft', 'wave']
# 		Skulls, genres = ['alternative', 'pop', 'rock']
# 		Namaste - Alternate Mix / No Vocals, genres = ['alternative', 'hip hop', 'rap', 'rock']
# 		You're My Latest, My Greatest Inspiration, genres = ['classic', 'contemporary', 'funk', 'soul', 'southern', 'swing']
# 		Homeless Brother, genres = ['adult standards', 'classic', 'folk', 'mellow gold', 'rock', 'singer songwriter', 'soft', 'traditional']
# 		A Place to Fall Apart (with Janie Fricke), genres = ['country', 'rock']
# 		עוף גוזל, genres = ['classic', 'pop', 'rock', 'singer songwriter']
# 		It Don't Matter to Me, genres = ['adult standards', 'folk', 'mellow gold', 'rock', 'soft']
# 		Rosemary - 2013 Remaster, genres = ['classic', 'country', 'folk', 'mellow gold', 'psychedelic', 'rock', 'roots']
# 		Desperado, genres = ['country', 'rock', 'roots']
# 	Recommendations Based On 13 Preludes, Op. 32: No. 9 in A Major: Allegro moderato, genres = ['classical', 'romantic', 'romantic era']
# 		Impromptu No. 1 in A-Flat Major, Op. 29, genres = ['classical', 'romantic', 'romantic era']
# 		Lucy Takes Gull Cottage, genres = ['classic']
# 		Chopin: Nocturne No. 19 in E Minor, Op. Posth. 72 No. 1, genres = ['classical', 'romantic', 'romantic era']
# 		Ballade No. 4 in F Minor, Op. 52, genres = ['classical', 'romantic', 'romantic era']
# 		Mazurkas, Op. 59: No. 3 in F-Sharp Minor, genres = ['classical', 'romantic', 'romantic era']
# 		12 études, Op. 10: No. 9 in F Minor, genres = ['classical', 'romantic', 'romantic era']
# 		Straniero tra gli angeli, genres = ['classic', 'pop', 'swing']
# 		Chopin: Nocturne No. 2 in E-Flat Major, Op. 9 No. 2, genres = ['classical', 'romantic', 'romantic era']
# 		Nocturne in B Major, Op. 9, No. 3 - 2001 Remastered, genres = ['classical', 'romantic', 'romantic era']
# 		Allemande (beginning), genres = ['classical']
# Affinity Propagation
# 	Recommendations Based On Bohemian Rhapsody, genres = ['modern', 'pop', 'rock']
# 		Look After You, genres = ['modern', 'pop', 'rock']
# 		East To West, genres = ['alternative', 'rock']
# 		It Ends Tonight, genres = ['grunge', 'modern', 'pop', 'punk', 'rock']
# 		Born To Die, genres = ['art', 'pop']
# 		Princess of China, genres = ['pop', 'wave']
# 		Eventually, genres = ['psychedelic']
# 		Memories, genres = ['metal']
# 		Bella (She's All I Ever Had), genres = ['dance', 'latin', 'pop']
# 		Ana's Song (Open Fire), genres = ['alternative', 'grunge', 'metal', 'pop', 'rock']
# 		Gasoline, genres = ['alternative', 'grunge', 'metal', 'modern', 'rock', 'wave']
# 	Recommendations Based On Baby, genres = ['funk', 'rock']
# 		I Still Can't Believe You're Gone, genres = ['classic', 'country', 'pop', 'rock', 'singer songwriter']
# 		Filles de Kilimanjaro, genres = ['bebop', 'bop', 'contemporary', 'cool', 'hard', 'jazz']
# 		The Snow Maiden: Dance of the Tumblers, genres = ['classical', 'romantic', 'romantic era']
# 		Jagger the Dagger, genres = ['funk', 'jazz', 'soul']
# 		Caroline, No - Remastered, genres = ['classic', 'folk', 'pop', 'psychedelic', 'rock']
# 		Like Sonny - Alternate Take, genres = ['bebop', 'bop', 'contemporary', 'cool', 'jazz']
# 		Chase The Clouds Away, genres = ['jazz']
# 		You And Me Against The World, genres = ['adult standards', 'folk', 'mellow gold', 'pop', 'rock', 'soft']
# 		Third Week in the Chelsea, genres = ['art', 'classic', 'folk', 'psychedelic', 'rock', 'roots']
# 		Forever More, genres = ['classic', 'funk', 'soul']
# 	Recommendations Based On 13 Preludes, Op. 32: No. 9 in A Major: Allegro moderato, genres = ['classical', 'romantic', 'romantic era']
# 		Impromptu No. 1 in A-Flat Major, Op. 29, genres = ['classical', 'romantic', 'romantic era']
# 		Lucy Takes Gull Cottage, genres = ['classic']
# 		Chopin: Nocturne No. 19 in E Minor, Op. Posth. 72 No. 1, genres = ['classical', 'romantic', 'romantic era']
# 		Ballade No. 4 in F Minor, Op. 52, genres = ['classical', 'romantic', 'romantic era']
# 		Mazurkas, Op. 59: No. 3 in F-Sharp Minor, genres = ['classical', 'romantic', 'romantic era']
# 		Straniero tra gli angeli, genres = ['classic', 'pop', 'swing']
# 		Chopin: Nocturne No. 2 in E-Flat Major, Op. 9 No. 2, genres = ['classical', 'romantic', 'romantic era']
# 		Allemande (beginning), genres = ['classical']
# 		Four Impromtus, Op. 90, D. 899: No. 3. Andante in G-Flat Major, genres = ['classical', 'romantic', 'romantic era']
# 		Smile, genres = ['classic', 'pop', 'swing']
# Agglomerative Clustering
# 	Recommendations Based On Bohemian Rhapsody, genres = ['modern', 'pop', 'rock']
# 		East To West, genres = ['alternative', 'rock']
# 		Bored, genres = ['alternative', 'grunge', 'indie', 'metal', 'modern', 'rap', 'rock']
# 		Until We Meet Again, genres = ['dance', 'pop']
# 		Mi soledad y yo, genres = ['latin', 'pop', 'rock']
# 		I Feel Pretty / Unpretty (Glee Cast Version), genres = ['pop']
# 		One And Only, genres = ['pop', 'soul']
# 		Numb, genres = ['art', 'pop']
# 		Outfit, genres = ['alternative', 'country', 'folk', 'rock', 'roots', 'southern']
# 		Those I've Loved, genres = ['contemporary', 'country', 'modern', 'rock']
# 		Stay With Me, genres = ['pop']
# 	Recommendations Based On Baby, genres = ['funk', 'rock']
# 		Blood Of Eden, genres = ['album', 'art', 'classic', 'dance', 'mellow gold', 'pop', 'rock', 'soft', 'wave']
# 		Skulls, genres = ['alternative', 'pop', 'rock']
# 		Namaste - Alternate Mix / No Vocals, genres = ['alternative', 'hip hop', 'rap', 'rock']
# 		You're My Latest, My Greatest Inspiration, genres = ['classic', 'contemporary', 'funk', 'soul', 'southern', 'swing']
# 		Homeless Brother, genres = ['adult standards', 'classic', 'folk', 'mellow gold', 'rock', 'singer songwriter', 'soft', 'traditional']
# 		A Place to Fall Apart (with Janie Fricke), genres = ['country', 'rock']
# 		עוף גוזל, genres = ['classic', 'pop', 'rock', 'singer songwriter']
# 		It Don't Matter to Me, genres = ['adult standards', 'folk', 'mellow gold', 'rock', 'soft']
# 		Rosemary - 2013 Remaster, genres = ['classic', 'country', 'folk', 'mellow gold', 'psychedelic', 'rock', 'roots']
# 		Desperado, genres = ['country', 'rock', 'roots']
# 	Recommendations Based On 13 Preludes, Op. 32: No. 9 in A Major: Allegro moderato, genres = ['classical', 'romantic', 'romantic era']
# 		Impromptu No. 1 in A-Flat Major, Op. 29, genres = ['classical', 'romantic', 'romantic era']
# 		Lucy Takes Gull Cottage, genres = ['classic']
# 		Chopin: Nocturne No. 19 in E Minor, Op. Posth. 72 No. 1, genres = ['classical', 'romantic', 'romantic era']
# 		Ballade No. 4 in F Minor, Op. 52, genres = ['classical', 'romantic', 'romantic era']
# 		Mazurkas, Op. 59: No. 3 in F-Sharp Minor, genres = ['classical', 'romantic', 'romantic era']
# 		12 études, Op. 10: No. 9 in F Minor, genres = ['classical', 'romantic', 'romantic era']
# 		Straniero tra gli angeli, genres = ['classic', 'pop', 'swing']
# 		Chopin: Nocturne No. 2 in E-Flat Major, Op. 9 No. 2, genres = ['classical', 'romantic', 'romantic era']
# 		Nocturne in B Major, Op. 9, No. 3 - 2001 Remastered, genres = ['classical', 'romantic', 'romantic era']
# 		Allemande (beginning), genres = ['classical']
# Spectral Clustering
# 	Recommendations Based On Bohemian Rhapsody, genres = ['modern', 'pop', 'rock']
# 		Look After You, genres = ['modern', 'pop', 'rock']
# 		East To West, genres = ['alternative', 'rock']
# 		Bored, genres = ['alternative', 'grunge', 'indie', 'metal', 'modern', 'rap', 'rock']
# 		It Ends Tonight, genres = ['grunge', 'modern', 'pop', 'punk', 'rock']
# 		Born To Die, genres = ['art', 'pop']
# 		Until We Meet Again, genres = ['dance', 'pop']
# 		Princess of China, genres = ['pop', 'wave']
# 		Mi soledad y yo, genres = ['latin', 'pop', 'rock']
# 		Eventually, genres = ['psychedelic']
# 		I Feel Pretty / Unpretty (Glee Cast Version), genres = ['pop']
# 	Recommendations Based On Baby, genres = ['funk', 'rock']
# 		Blood Of Eden, genres = ['album', 'art', 'classic', 'dance', 'mellow gold', 'pop', 'rock', 'soft', 'wave']
# 		Skulls, genres = ['alternative', 'pop', 'rock']
# 		Namaste - Alternate Mix / No Vocals, genres = ['alternative', 'hip hop', 'rap', 'rock']
# 		You're My Latest, My Greatest Inspiration, genres = ['classic', 'contemporary', 'funk', 'soul', 'southern', 'swing']
# 		Homeless Brother, genres = ['adult standards', 'classic', 'folk', 'mellow gold', 'rock', 'singer songwriter', 'soft', 'traditional']
# 		A Place to Fall Apart (with Janie Fricke), genres = ['country', 'rock']
# 		עוף גוזל, genres = ['classic', 'pop', 'rock', 'singer songwriter']
# 		It Don't Matter to Me, genres = ['adult standards', 'folk', 'mellow gold', 'rock', 'soft']
# 		Rosemary - 2013 Remaster, genres = ['classic', 'country', 'folk', 'mellow gold', 'psychedelic', 'rock', 'roots']
# 		Desperado, genres = ['country', 'rock', 'roots']
# 	Recommendations Based On 13 Preludes, Op. 32: No. 9 in A Major: Allegro moderato, genres = ['classical', 'romantic', 'romantic era']
# 		Impromptu No. 1 in A-Flat Major, Op. 29, genres = ['classical', 'romantic', 'romantic era']
# 		Lucy Takes Gull Cottage, genres = ['classic']
# 		Chopin: Nocturne No. 19 in E Minor, Op. Posth. 72 No. 1, genres = ['classical', 'romantic', 'romantic era']
# 		Ballade No. 4 in F Minor, Op. 52, genres = ['classical', 'romantic', 'romantic era']
# 		Mazurkas, Op. 59: No. 3 in F-Sharp Minor, genres = ['classical', 'romantic', 'romantic era']
# 		12 études, Op. 10: No. 9 in F Minor, genres = ['classical', 'romantic', 'romantic era']
# 		Straniero tra gli angeli, genres = ['classic', 'pop', 'swing']
# 		Chopin: Nocturne No. 2 in E-Flat Major, Op. 9 No. 2, genres = ['classical', 'romantic', 'romantic era']
# 		Nocturne in B Major, Op. 9, No. 3 - 2001 Remastered, genres = ['classical', 'romantic', 'romantic era']
# 		Allemande (beginning), genres = ['classical']
# Gaussian Mixtures
# 	Recommendations Based On Bohemian Rhapsody, genres = ['modern', 'pop', 'rock']
# 		Look After You, genres = ['modern', 'pop', 'rock']
# 		East To West, genres = ['alternative', 'rock']
# 		It Ends Tonight, genres = ['grunge', 'modern', 'pop', 'punk', 'rock']
# 		Born To Die, genres = ['art', 'pop']
# 		Until We Meet Again, genres = ['dance', 'pop']
# 		Mi soledad y yo, genres = ['latin', 'pop', 'rock']
# 		Eventually, genres = ['psychedelic']
# 		I Feel Pretty / Unpretty (Glee Cast Version), genres = ['pop']
# 		Memories, genres = ['metal']
# 		One And Only, genres = ['pop', 'soul']
# 	Recommendations Based On Baby, genres = ['funk', 'rock']
# 		My Jelly Roll Soul, genres = ['bebop', 'bop', 'contemporary', 'cool', 'hard', 'jazz']
# 		Life Is Just A Bowl Of Cherries, genres = ['adult standards', 'jazz', 'lounge', 'vocal']
# 		Willow Weep For Me, genres = ['adult standards', 'blues', 'jazz', 'swing', 'vocal']
# 		Rocket Love, genres = ['funk', 'soul']
# 		Teach Me Tonight, genres = ['adult standards', 'blues', 'jazz', 'lounge', 'soul', 'swing', 'vocal']
# 		Milkcow's Calf Blues, genres = ['blues', 'rock', 'traditional']
# 		Introduction and Theme, genres = ['country', 'traditional']
# 		I'm Sticking With You, genres = ['alternative', 'art', 'classic', 'folk', 'psychedelic', 'rock', 'wave']
# 		Ooh Boy, genres = ['classic', 'contemporary', 'funk', 'soul']
# 		Pop's Confessin', genres = ['bebop', 'bop', 'contemporary', 'cool', 'hard', 'jazz', 'latin', 'soul', 'swing', 'vocal']
# 	Recommendations Based On 13 Preludes, Op. 32: No. 9 in A Major: Allegro moderato, genres = ['classical', 'romantic', 'romantic era']
# 		Impromptu No. 1 in A-Flat Major, Op. 29, genres = ['classical', 'romantic', 'romantic era']
# 		Lucy Takes Gull Cottage, genres = ['classic']
# 		Chopin: Nocturne No. 19 in E Minor, Op. Posth. 72 No. 1, genres = ['classical', 'romantic', 'romantic era']
# 		Ballade No. 4 in F Minor, Op. 52, genres = ['classical', 'romantic', 'romantic era']
# 		Mazurkas, Op. 59: No. 3 in F-Sharp Minor, genres = ['classical', 'romantic', 'romantic era']
# 		12 études, Op. 10: No. 9 in F Minor, genres = ['classical', 'romantic', 'romantic era']
# 		Straniero tra gli angeli, genres = ['classic', 'pop', 'swing']
# 		Chopin: Nocturne No. 2 in E-Flat Major, Op. 9 No. 2, genres = ['classical', 'romantic', 'romantic era']
# 		Nocturne in B Major, Op. 9, No. 3 - 2001 Remastered, genres = ['classical', 'romantic', 'romantic era']
# 		Allemande (beginning), genres = ['classical']
